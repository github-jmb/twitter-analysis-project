# %%
import pandas as pd

# %%
df = pd.read_csv('Tweets_Overall.csv')
df.shape
# Out:
# (16598, 6)

# %%
df.sample(n=10)
# Out:
#                     club                   id                  createdAt  \
# 6173             Arsenal  1579232985953751040  2022-10-09 22:10:59+00:00
# 6296             Arsenal  1576200571433820160  2022-10-01 13:21:15+00:00
# 122    Manchester United  1582626349788848128  2022-10-19 06:55:00+00:00
# 2289   Manchester United  1529231517758607361  2022-05-24 22:43:00+00:00
# 139    Manchester United  1582316292618321921  2022-10-18 10:22:56+00:00
# 1709   Manchester United  1548021076923408384  2022-07-15 19:06:00+00:00
# 11025            Chelsea  1527270994804723713  2022-05-19 12:52:35+00:00
# 11262            Chelsea  1522958790542249985  2022-05-07 15:17:25+00:00
# 9602             Chelsea  1567190035518062595  2022-09-06 16:36:36+00:00
# 15912          Tottenham  1518969240572862464  2022-04-26 15:04:22+00:00
#
#        favorites  retweets                                               text
# 6173       58366      5786  Most ground duels (7) Most aerial duels (4) Mo...
# 6296      110933     25170  Energy. Commitment. Passion.  We did this toge...
# 122        13252      1075  ☕ Good morning from Old Trafford.  #MUFC || #M...
# 2289        6563       414  🎨 #UnitedFanArt fit for a King 👑  👨‍🎨 @Shanmuk...
# 139         5166       412  3️⃣ countries 🌍 2️⃣ matches ⚽️ 1️⃣ incredible ...
# 1709       11826       532                 Representing 🔴  #MUFC || #MUTOUR22
# 11025       6847       563  Congratulations on your 1500th competitive Che...
# 11262      12714      1667  ROM AGAIN! 😎  🔵 2-0 🐺 [58] #CheWol https://t.c...
# 9602        6659       527  The players will be with us shortly! 🤝  #UCL h...
# 15912      10184       277  Come back stronger, Skippy. ✊ https://t.co/7Tx...

# %%
df['club'].value_counts()
# Out:
# club
# Manchester United    3005
# Chelsea              3005
# Liverpool FC         2975
# Arsenal              2894
# Tottenham            2745
# Manchester City      1974
# Name: count, dtype: int64

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
dfLiverpool = df.loc[df['club']=='Liverpool FC']

fig = make_subplots(rows=1, cols=1,)

fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], 
        y=dfLiverpool['favorites'],
        name="Liverpool FC Favorites"),row=1, col=1)

fig.update_layout(height=500, width=700,
        title_text="Premier League Twitter Analysis - Favorite Count")

fig.show()

# %%
dfLiverpool = df.loc[df['club']=='Liverpool FC']
dfManU = df.loc[df['club']=='Manchester United']
dfArsenal = df.loc[df['club']=='Arsenal']
dfChelsea = df.loc[df['club']=='Chelsea']
dfManCity = df.loc[df['club']=='Manchester City']
dfSpurs = df.loc[df['club']=='Tottenham']

# %%
fig = make_subplots(
    rows=6, cols=1
    )

fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], y=dfLiverpool['favorites'],
              name="Liverpool FC Favorites"),
              row=1, col=1)

fig.add_trace(go.Scatter(x=dfManU['createdAt'], y=dfManU['favorites'],
              name="Manchester United Favorites"),
              row=2, col=1)

fig.add_trace(go.Scatter(x=dfArsenal['createdAt'], y=dfArsenal['favorites'],
              name="Arsenal Favorites"),
              row=3, col=1)

fig.add_trace(go.Scatter(x=dfManCity['createdAt'], y=dfManCity['favorites'],
              name="Manchester City Favorites"),
              row=4, col=1)

fig.add_trace(go.Scatter(x=dfSpurs['createdAt'], y=dfSpurs['favorites'],
              name="Tottenham Hotspur Favorites"),
              row=5, col=1)

fig.add_trace(go.Scatter(x=dfChelsea['createdAt'], y=dfChelsea['favorites'],
              name="Chelsea Favorites"),
              row=6, col=1)

fig.update_layout(height=500, width=700,
                  title_text="Premier League Twitter Analysis - Favorite Count")

fig.show()

# %%
df.sort_values('favorites', ascending=False)
# Out:
#                     club                   id                  createdAt  \
# 10888            Chelsea  1530663553316929539  2022-05-28 21:33:24+00:00
# 5324        Liverpool FC  1530620336915480576  2022-05-28 18:41:40+00:00
# 9583             Chelsea  1567438886594281472  2022-09-07 09:05:26+00:00
# 360    Manchester United  1579183525634650112  2022-10-09 18:54:26+00:00
# 2917   Manchester United  1517083257539637248  2022-04-21 10:10:09+00:00
# ...                  ...                  ...                        ...
# 15889          Tottenham  1520380448844746752  2022-04-30 12:32:00+00:00
# 16593          Tottenham  1500077083183226880  2022-03-05 11:53:41+00:00
# 15890          Tottenham  1520363666239107073  2022-04-30 11:25:19+00:00
# 15948          Tottenham  1517835431466913793  2022-04-23 11:59:01+00:00
# 13853          Tottenham  1584221496205090817  2022-10-23 16:33:32+00:00
#
#        favorites  retweets                                               text
# 10888     353619     37729                       Congratulations @RealMadrid.
# 5324      282964     40385                          You'll Never Walk Alone ❤
# 9583      275002     49135  Chelsea Football Club part company with Thomas...
# 360       257905     31399               Astonishing. https://t.co/0UWTNQZm6U
# 2917      257525     62960  🇳🇱👔  The new First-Team Manager of Manchester ...
# ...          ...       ...                                                ...
# 15889        340        19  Having equalised mid-way through the second ha...
# 16593        301         8  Our U18s trail at the break against @FulhamFC....
# 15890        298        15  Our U18s took the upper hand early at @Norwich...
# 15948        263        12  Our U18s are a goal down after a first half of...
# 13853        258        19                              Back underway in N17.
#
# [16598 rows x 6 columns]

# %%
df.loc[df['club']=='Chelsea'].sort_values('favorites', ascending=False)
# Out:
#           club                   id                  createdAt  favorites  \
# 10888  Chelsea  1530663553316929539  2022-05-28 21:33:24+00:00     353619
# 9583   Chelsea  1567438886594281472  2022-09-07 09:05:26+00:00     275002
# 9580   Chelsea  1567886827305975808  2022-09-08 14:45:24+00:00     223220
# 10539  Chelsea  1547249569565532167  2022-07-13 16:00:18+00:00     216418
# 10173  Chelsea  1555512782799396869  2022-08-05 11:15:22+00:00     204721
# ...        ...                  ...                        ...        ...
# 11479  Chelsea  1518235857572044801  2022-04-24 14:30:10+00:00       1318
# 11077  Chelsea  1525543860679725058  2022-05-14 18:29:34+00:00       1295
# 10368  Chelsea  1549922408131346434  2022-07-21 01:01:12+00:00       1229
# 11079  Chelsea  1525543431203958786  2022-05-14 18:27:51+00:00       1181
# 11083  Chelsea  1525542626732171264  2022-05-14 18:24:40+00:00       1169
#
#        retweets                                               text
# 10888     37729                       Congratulations @RealMadrid.
# 9583      49135  Chelsea Football Club part company with Thomas...
# 9580      35552  Chelsea Football Club is delighted to welcome ...
# 10539     34901  A star in LA! 🇺🇸  #SterlingIsChelsea https://t...
# 10173     31623  CLUB STATEMENT: MARC CUCURELLA.   Following re...
# ...         ...                                                ...
# 11479        79  Mount gets to the byline and cuts it back into...
# 11077       115  Alexander-Arnold scores.  🟡 3-4 🔴 | #EmiratesF...
# 10368        87  Yordi Reina's deflected effort comes back off ...
# 11079       106          Firmino scores.  🟡 2-3 🔴 | #EmiratesFACup
# 11083       124  Milner for Liverpool, scores.  🟡 1-1 🔴 | #Emir...
#
# [3005 rows x 6 columns]

# %%
df.loc[df['club']=='Liverpool FC'].sort_values('favorites', ascending=False)
# Out:
#               club                   id                  createdAt  favorites  \
# 5324  Liverpool FC  1530620336915480576  2022-05-28 18:41:40+00:00     282964
# 5034  Liverpool FC  1539569839832023047  2022-06-22 11:23:48+00:00     218420
# 5690  Liverpool FC  1525545497565577216  2022-05-14 18:36:04+00:00     200256
# 5976  Liverpool FC  1521593537007165441  2022-05-03 20:52:23+00:00     182939
# 5949  Liverpool FC  1521966957188333568  2022-05-04 21:36:14+00:00     179487
# ...            ...                  ...                        ...        ...
# 3021  Liverpool FC  1583787927871848449  2022-10-22 11:50:42+00:00        804
# 3795  Liverpool FC  1566046230324584448  2022-09-03 12:51:31+00:00        803
# 3806  Liverpool FC  1566027898083020800  2022-09-03 11:38:40+00:00        793
# 3720  Liverpool FC  1567596206393643009  2022-09-07 19:30:34+00:00        792
# 3016  Liverpool FC  1583799442360049664  2022-10-22 12:36:27+00:00        783
#
#       retweets                                               text
# 5324     40385                          You'll Never Walk Alone ❤
# 5034     23529  269 games 🏟️ 120 goals ⚽ 38 assists 🅰️  Thank ...
# 5690     62417  WE ARE THE #EmiratesFACup WINNERS!!!!!!! https...
# 5976     32020                        👋🇫🇷 https://t.co/eaqKMWv7Zy
# 5949     26275  We’ll face @realmadrid in the #UCL final 👊 htt...
# ...        ...                                                ...
# 3021        58  20' - Robertson picks out the run of Jones dow...
# 3795        62  64' - Firmino's low shot bounces just in front...
# 3806        64  8' - An assertive start from the Reds, but Eve...
# 3720        58  30' - Elliott threads a lovely ball into Salah...
# 3016        53  50' - Milner's deep cross sees Carvalho get a ...
#
# [2975 rows x 6 columns]

# %%
df.loc[df['club']=='Manchester United'].sort_values('favorites', ascending=False)
# Out:
#                    club                   id                  createdAt  \
# 360   Manchester United  1579183525634650112  2022-10-09 18:54:26+00:00
# 2917  Manchester United  1517083257539637248  2022-04-21 10:10:09+00:00
# 1197  Manchester United  1560707140918067201  2022-08-19 19:15:53+00:00
# 1019  Manchester United  1564583777019609088  2022-08-30 12:00:15+00:00
# 2914  Manchester United  1517095827109515264  2022-04-21 11:00:06+00:00
# ...                 ...                  ...                        ...
# 2813  Manchester United  1519291587032985600  2022-04-27 12:25:16+00:00
# 0     Manchester United  1584215844112171008  2022-10-23 16:11:05+00:00
# 2933  Manchester United  1516508393367822344  2022-04-19 20:05:50+00:00
# 2374  Manchester United  1528029126233313280  2022-05-21 15:05:07+00:00
# 2569  Manchester United  1522993070081462272  2022-05-07 17:33:38+00:00
#
#       favorites  retweets                                               text
# 360      257905     31399               Astonishing. https://t.co/0UWTNQZm6U
# 2917     257525     62960  🇳🇱👔  The new First-Team Manager of Manchester ...
# 1197     249756     43517  We are delighted to have reached an agreement ...
# 1019     197642     33954  An agreement has been reached for the transfer...
# 2914     188666     24764  New beginnings.  🔴⚪⚫ x 🔴⚪🔵  #MUFC || #WelcomeE...
# ...         ...       ...                                                ...
# 2813       1213       101  🔊 Ralf's press conference is about to get unde...
# 0          1207       118  Well played, @ManUtdWomen! 💪  #MUFC || #MUWome...
# 2933       1132       109         Play resumes at Anfield.   #MUFC | #LIVMUN
# 2374       1026        86  We're back under way at Old Trafford — with th...
# 2569        996       116  We're back under way for the second half. Time...
#
# [3005 rows x 6 columns]

# %%
df.loc[df['club']=='Arsenal'].sort_values('favorites', ascending=False)
# Out:
#          club                   id                  createdAt  favorites  \
# 6998  Arsenal  1550526088190861313  2022-07-22 17:00:01+00:00     216027
# 7182  Arsenal  1543863208569708544  2022-07-04 07:44:07+00:00     185775
# 6184  Arsenal  1579162432764723200  2022-10-09 17:30:38+00:00     173072
# 7177  Arsenal  1543925323175268353  2022-07-04 11:50:56+00:00     171402
# 6183  Arsenal  1579164240463552512  2022-10-09 17:37:49+00:00     162642
# ...       ...                  ...                        ...        ...
# 8365  Arsenal  1491853464040787970  2022-02-10 19:15:57+00:00        698
# 8634  Arsenal  1480241448213786632  2022-01-09 18:13:57+00:00        651
# 7784  Arsenal  1512809252926205961  2022-04-09 15:06:47+00:00        635
# 7842  Arsenal  1511071985333420043  2022-04-04 20:03:30+00:00        606
# 7791  Arsenal  1512787419241889792  2022-04-09 13:40:01+00:00        556
#
#       retweets                                               text
# 6998     29010                                💛🖤 Welcome, Alex 🖤💛
# 7182     31678  ⛅️ On Cloud No. 9  🔴 Welcome to Arsenal, Gabri...
# 6184     36591               THIS TEAM ❤️ https://t.co/484bcUc3Xw
# 7177     19656  🇧🇷 Gabi x Gabi x Gabby 🇧🇷 https://t.co/vvew1HTRPb
# 6183     26201        WE ARE THE ARSENAL. https://t.co/S8RTX1ybIn
# ...        ...                                                ...
# 8365        42  ⏯ Now playing: The Breakdown LIVE  Join us for...
# 8634        52  ▶️ We're back for the second half...  📻 Rememb...
# 7784        62  🚨 We're back underway in N5!  ✊ COME ON ARSENA...
# 7842        58  Back at it for a big second half...  COME ON L...
# 7791        56  📺 The Breakdown Live... is LIVE!  Join @NickBr...
#
# [2894 rows x 6 columns]

# %%
df.loc[df['club']=='Manchester City'].sort_values('favorites', ascending=False)
# Out:
#                   club                   id                  createdAt  \
# 13701  Manchester City  1545815047103844352  2022-07-09 17:00:01+00:00
# 11982  Manchester City  1582097115039166464  2022-10-17 19:52:00+00:00
# 13715  Manchester City  1545331903510859776  2022-07-08 09:00:11+00:00
# 13712  Manchester City  1545340458355900418  2022-07-08 09:34:10+00:00
# 12327  Manchester City  1577205747137409026  2022-10-04 07:55:27+00:00
# ...                ...                  ...                        ...
# 11906  Manchester City  1583832888524492800  2022-10-22 14:49:21+00:00
# 12027  Manchester City  1581633321439633410  2022-10-16 13:09:03+00:00
# 12493  Manchester City  1574697772888260609  2022-09-27 09:49:40+00:00
# 12128  Manchester City  1579804778171084801  2022-10-11 12:03:05+00:00
# 11880  Manchester City  1584182857014030338  2022-10-23 14:00:00+00:00
#
#        favorites  retweets                                               text
# 13701     123320      7382                      👕9️⃣💙 https://t.co/IHcyiPRiZg
# 11982     123008     15095  #BallonDor Club of the Year!!! 🎉 https://t.co/...
# 13715     105698      9478  We are delighted to confirm the arrival of Jul...
# 13712      96565      6893  Our new number 1️⃣9️⃣🕷  #ManCity https://t.co/...
# 12327      78764      4139  Haaland ⚽️⚽️⚽️ Foden ⚽️⚽️⚽️ https://t.co/8i5ZQ...
# ...          ...       ...                                                ...
# 11906        592        49  Hear what our Matchday Live guests’ have to sa...
# 12027        567        51  Good luck, girls! 💙  Watch it live 📺  CITY+ ▶️...
# 12493        536        26  👏 Mary Fowler 👏 👏 @HayleyRaso 👏 https://t.co/2...
# 12128        505        26  Our EDS are live on CITY+ and @RecastTV in the...
# 11880        350        27  .@Chloe_Kelly98 &amp; @lauren__hemp take on th...
#
# [1974 rows x 6 columns]

# %%
df.loc[df['club']=='Tottenham'].sort_values('favorites', ascending=False)
# Out:
#             club                   id                  createdAt  favorites  \
# 15534  Tottenham  1528420824591523843  2022-05-22 17:01:35+00:00     206968
# 15818  Tottenham  1521600988318162945  2022-05-03 21:22:00+00:00     183503
# 15530  Tottenham  1528448858342162434  2022-05-22 18:52:59+00:00     126059
# 15446  Tottenham  1532372588604841995  2022-06-02 14:44:29+00:00     118808
# 15537  Tottenham  1528413984688422912  2022-05-22 16:34:25+00:00     114026
# ...          ...                  ...                        ...        ...
# 15889  Tottenham  1520380448844746752  2022-04-30 12:32:00+00:00        340
# 16593  Tottenham  1500077083183226880  2022-03-05 11:53:41+00:00        301
# 15890  Tottenham  1520363666239107073  2022-04-30 11:25:19+00:00        298
# 15948  Tottenham  1517835431466913793  2022-04-23 11:59:01+00:00        263
# 13853  Tottenham  1584221496205090817  2022-10-23 16:33:32+00:00        258
#
#        retweets                                               text
# 15534     35238  Premier League Golden Boot winner: Heung-Min S...
# 15818      3026   It couldn't, could it... https://t.co/9MUpZhAoUI
# 15530     10458                            https://t.co/5jRFgz4fvT
# 15446      5491  🇰🇷 @Sonny7 x @neymarjr 🇧🇷 https://t.co/9T985zKd15
# 15537     13126           Heung-Min Son is a very good footballer.
# ...         ...                                                ...
# 15889        19  Having equalised mid-way through the second ha...
# 16593         8  Our U18s trail at the break against @FulhamFC....
# 15890        15  Our U18s took the upper hand early at @Norwich...
# 15948        12  Our U18s are a goal down after a first half of...
# 13853        19                              Back underway in N17.
#
# [2745 rows x 6 columns]

# %%
dfLiverpool = df.loc[df['club']=='Liverpool FC']
dfManU = df.loc[df['club']=='Manchester United']
dfArsenal = df.loc[df['club']=='Arsenal']
dfChelsea = df.loc[df['club']=='Chelsea']
dfManCity = df.loc[df['club']=='Manchester City']
dfSpurs = df.loc[df['club']=='Tottenham']

# %%
fig = make_subplots(
    rows=6, cols=1
    )

fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], y=dfLiverpool['retweets'],
              name="Liverpool FC Retweets"),
              row=1, col=1)

fig.add_trace(go.Scatter(x=dfManU['createdAt'], y=dfManU['retweets'],
              name="Manchester United Retweets"),
              row=2, col=1)

fig.add_trace(go.Scatter(x=dfArsenal['createdAt'], y=dfArsenal['retweets'],
              name="Arsenal Retweets"),
              row=3, col=1)

fig.add_trace(go.Scatter(x=dfManCity['createdAt'], y=dfManCity['retweets'],
              name="Manchester City Retweets"),
              row=4, col=1)

fig.add_trace(go.Scatter(x=dfSpurs['createdAt'], y=dfSpurs['retweets'],
              name="Tottenham Hotspur Retweets"),
              row=5, col=1)

fig.add_trace(go.Scatter(x=dfChelsea['createdAt'], y=dfChelsea['retweets'],
              name="Chelsea Retweets"),
              row=6, col=1)

fig.update_layout(height=500, width=700,
                  title_text="Premier League Twitter Analysis - Retweet Count")

fig.show()

# %%
df.loc[df['club']=='Liverpool FC'].sort_values('retweets', ascending=False)
# Out:
#               club                   id                  createdAt  favorites  \
# 5690  Liverpool FC  1525545497565577216  2022-05-14 18:36:04+00:00     200256
# 5324  Liverpool FC  1530620336915480576  2022-05-28 18:41:40+00:00     282964
# 5976  Liverpool FC  1521593537007165441  2022-05-03 20:52:23+00:00     182939
# 5689  Liverpool FC  1525545997614694400  2022-05-14 18:38:03+00:00     128326
# 5949  Liverpool FC  1521966957188333568  2022-05-04 21:36:14+00:00     179487
# ...            ...                  ...                        ...        ...
# 3388  Liverpool FC  1577396085147975680  2022-10-04 20:31:47+00:00        944
# 5828  Liverpool FC  1524114352751714304  2022-05-10 19:49:13+00:00        936
# 4365  Liverpool FC  1553831398603202561  2022-07-31 19:54:08+00:00        963
# 4364  Liverpool FC  1553833911477833728  2022-07-31 20:04:07+00:00        824
# 4373  Liverpool FC  1553813650338619393  2022-07-31 18:43:37+00:00       1051
#
#       retweets                                               text
# 5690     62417  WE ARE THE #EmiratesFACup WINNERS!!!!!!! https...
# 5324     40385                          You'll Never Walk Alone ❤
# 5976     32020                        👋🇫🇷 https://t.co/eaqKMWv7Zy
# 5689     26788  Set complete for the boss 😍🏆  #EmiratesFACup h...
# 5949     26275  We’ll face @realmadrid in the #UCL final 👊 htt...
# ...        ...                                                ...
# 3388        48  74' - Nunez beats McGregor to the ball after S...
# 5828        47  48' - Trent's corner is re-taken, Jota peels o...
# 4365        44  66' - Morton's strike is parried by Sels, Frau...
# 4364        44  76' - Frauendorf's run in behind is picked out...
# 4373        43  12' - Carvalho is played in by Elliott after B...
#
# [2975 rows x 6 columns]

# %%
df.loc[df['club']=='Manchester United'].sort_values('retweets', ascending=False)
# Out:
#                    club                   id                  createdAt  \
# 2917  Manchester United  1517083257539637248  2022-04-21 10:10:09+00:00
# 1197  Manchester United  1560707140918067201  2022-08-19 19:15:53+00:00
# 514   Manchester United  1576475334811480064  2022-10-02 07:33:03+00:00
# 1715  Manchester United  1547944083800223745  2022-07-15 14:00:03+00:00
# 1019  Manchester United  1564583777019609088  2022-08-30 12:00:15+00:00
# ...                 ...                  ...                        ...
# 2961  Manchester United  1516152587463979012  2022-04-18 20:32:00+00:00
# 2815  Manchester United  1519262328226816001  2022-04-27 10:29:00+00:00
# 2374  Manchester United  1528029126233313280  2022-05-21 15:05:07+00:00
# 2373  Manchester United  1528029488117911558  2022-05-21 15:06:34+00:00
# 2369  Manchester United  1528033676545691649  2022-05-21 15:23:12+00:00
#
#       favorites  retweets                                               text
# 2917     257525     62960  🇳🇱👔  The new First-Team Manager of Manchester ...
# 1197     249756     43517  We are delighted to have reached an agreement ...
# 514      144203     36191  Manchester United is deeply saddened by the tr...
# 1715     158874     35623  Christian Eriksen is a RED! ✍️🔴  #MUFC || @Chr...
# 1019     197642     33954  An agreement has been reached for the transfer...
# ...         ...       ...                                                ...
# 2961       1447        99  🔊 Part two of our podcast episode with Steve C...
# 2815       1531        96  The #MUAcademy U18s travel to Wolves today for...
# 2374       1026        86  We're back under way at Old Trafford — with th...
# 2373       1318        85  The away side take the lead as Luis Garcia rou...
# 2369       1370        81  The away side retake the lead through a fine M...
#
# [3005 rows x 6 columns]

# %%
df.loc[df['club']=='Manchester City'].sort_values('retweets', ascending=False)
# Out:
#                   club                   id                  createdAt  \
# 11982  Manchester City  1582097115039166464  2022-10-17 19:52:00+00:00
# 12405  Manchester City  1576476461724098561  2022-10-02 07:37:32+00:00
# 13715  Manchester City  1545331903510859776  2022-07-08 09:00:11+00:00
# 12364  Manchester City  1576585447211667461  2022-10-02 14:50:36+00:00
# 13759  Manchester City  1543881834366439426  2022-07-04 08:58:07+00:00
# ...                ...                  ...                        ...
# 13846  Manchester City  1539200829764292609  2022-06-21 10:57:29+00:00
# 12973  Manchester City  1563480999090343938  2022-08-27 10:58:12+00:00
# 11880  Manchester City  1584182857014030338  2022-10-23 14:00:00+00:00
# 12493  Manchester City  1574697772888260609  2022-09-27 09:49:40+00:00
# 12128  Manchester City  1579804778171084801  2022-10-11 12:03:05+00:00
#
#        favorites  retweets                                               text
# 11982     123008     15095  #BallonDor Club of the Year!!! 🎉 https://t.co/...
# 12405      62209     13350  We are deeply saddened to hear of the tragic e...
# 13715     105698      9478  We are delighted to confirm the arrival of Jul...
# 12364      50400      9128  FULL-TIME | Manchester is BLUE! 💙  🔵 6-3 🔴 #Ma...
# 13759      49465      8711  We are delighted to announce the signing of @K...
# ...          ...       ...                                                ...
# 13846        695        36  Young Leaders Summit Day 1️⃣: Football, nutrit...
# 12973        821        35  𝗟𝗜𝗩𝗘 𝗙𝗢𝗢𝗧𝗕𝗔𝗟𝗟  Our Under 18s face Derby in the...
# 11880        350        27  .@Chloe_Kelly98 &amp; @lauren__hemp take on th...
# 12493        536        26  👏 Mary Fowler 👏 👏 @HayleyRaso 👏 https://t.co/2...
# 12128        505        26  Our EDS are live on CITY+ and @RecastTV in the...
#
# [1974 rows x 6 columns]

# %%
df.loc[df['club']=='Arsenal'].sort_values('retweets', ascending=False)
# Out:
#          club                   id                  createdAt  favorites  \
# 6184  Arsenal  1579162432764723200  2022-10-09 17:30:38+00:00     173072
# 7182  Arsenal  1543863208569708544  2022-07-04 07:44:07+00:00     185775
# 6998  Arsenal  1550526088190861313  2022-07-22 17:00:01+00:00     216027
# 6183  Arsenal  1579164240463552512  2022-10-09 17:37:49+00:00     162642
# 6296  Arsenal  1576200571433820160  2022-10-01 13:21:15+00:00     110933
# ...       ...                  ...                        ...        ...
# 8634  Arsenal  1480241448213786632  2022-01-09 18:13:57+00:00        651
# 8846  Arsenal  1473371441424855041  2021-12-21 19:15:00+00:00        703
# 8587  Arsenal  1481707556552724485  2022-01-13 19:19:44+00:00        823
# 8630  Arsenal  1480253130239533067  2022-01-09 19:00:22+00:00        758
# 8365  Arsenal  1491853464040787970  2022-02-10 19:15:57+00:00        698
#
#       retweets                                               text
# 6184     36591               THIS TEAM ❤️ https://t.co/484bcUc3Xw
# 7182     31678  ⛅️ On Cloud No. 9  🔴 Welcome to Arsenal, Gabri...
# 6998     29010                                💛🖤 Welcome, Alex 🖤💛
# 6183     26201        WE ARE THE ARSENAL. https://t.co/S8RTX1ybIn
# 6296     25170  Energy. Commitment. Passion.  We did this toge...
# ...        ...                                                ...
# 8634        52  ▶️ We're back for the second half...  📻 Rememb...
# 8846        51  📋 Team news discussion 🆚 Analysis of @Sunderla...
# 8587        50  ⏯ Now playing: The Breakdown Live! 🤩  📋 Team n...
# 8630        47  Our third substitution...  🔛 @SeadK6 ↩️ @Ofici...
# 8365        42  ⏯ Now playing: The Breakdown LIVE  Join us for...
#
# [2894 rows x 6 columns]

# %%
df.loc[df['club']=='Chelsea'].sort_values('retweets', ascending=False)
# Out:
#           club                   id                  createdAt  favorites  \
# 9583   Chelsea  1567438886594281472  2022-09-07 09:05:26+00:00     275002
# 10888  Chelsea  1530663553316929539  2022-05-28 21:33:24+00:00     353619
# 9580   Chelsea  1567886827305975808  2022-09-08 14:45:24+00:00     223220
# 10539  Chelsea  1547249569565532167  2022-07-13 16:00:18+00:00     216418
# 10173  Chelsea  1555512782799396869  2022-08-05 11:15:22+00:00     204721
# ...        ...                  ...                        ...        ...
# 11339  Chelsea  1520776937710444549  2022-05-01 14:47:31+00:00       1550
# 11479  Chelsea  1518235857572044801  2022-04-24 14:30:10+00:00       1318
# 10344  Chelsea  1549946929265655808  2022-07-21 02:38:39+00:00       1585
# 10346  Chelsea  1549946491837550592  2022-07-21 02:36:54+00:00       1445
# 10348  Chelsea  1549946152535162880  2022-07-21 02:35:34+00:00       1418
#
#        retweets                                               text
# 9583      49135  Chelsea Football Club part company with Thomas...
# 10888     37729                       Congratulations @RealMadrid.
# 9580      35552  Chelsea Football Club is delighted to welcome ...
# 10539     34901  A star in LA! 🇺🇸  #SterlingIsChelsea https://t...
# 10173     31623  CLUB STATEMENT: MARC CUCURELLA.   Following re...
# ...         ...                                                ...
# 11339        87  Ziyech's cross is saved by Pickford at one end...
# 11479        79  Mount gets to the byline and cuts it back into...
# 10344        78  PENALTIES:  Anton Walkes scores for Charlotte....
# 10346        78  PENALTIES:  Christian Makoun scores for Charlo...
# 10348        70  PENALTIES:  Rios scores for Charlotte with the...
#
# [3005 rows x 6 columns]

# %%
df.loc[df['club']=='Tottenham'].sort_values('retweets', ascending=False)
# Out:
#             club                   id                  createdAt  favorites  \
# 15534  Tottenham  1528420824591523843  2022-05-22 17:01:35+00:00     206968
# 15535  Tottenham  1528417734677221379  2022-05-22 16:49:19+00:00      88313
# 15537  Tottenham  1528413984688422912  2022-05-22 16:34:25+00:00     114026
# 15530  Tottenham  1528448858342162434  2022-05-22 18:52:59+00:00     126059
# 15321  Tottenham  1542780217562906624  2022-07-01 08:00:41+00:00      70045
# ...          ...                  ...                        ...        ...
# 15890  Tottenham  1520363666239107073  2022-04-30 11:25:19+00:00        298
# 15754  Tottenham  1523286614558277632  2022-05-08 13:00:04+00:00        445
# 15834  Tottenham  1521106470393286658  2022-05-02 12:36:57+00:00        492
# 15948  Tottenham  1517835431466913793  2022-04-23 11:59:01+00:00        263
# 16593  Tottenham  1500077083183226880  2022-03-05 11:53:41+00:00        301
#
#        retweets                                               text
# 15534     35238  Premier League Golden Boot winner: Heung-Min S...
# 15535     18469  Dare. Dream. Done. ✨  #UCL https://t.co/3DV07b...
# 15537     13126           Heung-Min Son is a very good footballer.
# 15530     10458                            https://t.co/5jRFgz4fvT
# 15321     10278  It's official 🔥   #WelcomeRicharlison https://...
# ...         ...                                                ...
# 15890        15  Our U18s took the upper hand early at @Norwich...
# 15754        15  It's all square at the break between our U23s ...
# 15834        14  It's been a story of important saves so far fo...
# 15948        12  Our U18s are a goal down after a first half of...
# 16593         8  Our U18s trail at the break against @FulhamFC....
#
# [2745 rows x 6 columns]
